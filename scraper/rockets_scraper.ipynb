# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import json
import pandas as pd

# %%
def scrape_rocket_data(url):
    # Fetch the content of the URL
    response = requests.get(url)
    html_content = response.content

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize dictionary to store the scraped data
    rocket_data = {}

    # Extract Rocket Name
    rocket_name_tag = soup.find("h3", class_="section--center mdl-grid")
    rocket_data["rocket_name"] = rocket_name_tag.text.strip() if rocket_name_tag else None

    # Rocket Details Link
    rocket_data["rocket_details_link"] = url

    # Get Rocket ID from the link
    rocket_data["rocket_id"] = url.split("/")[-1]

    # Extract Rocket Description
    description_section = soup.find("section", class_="card section--center white mdl-grid mdl-grid--no-spacing mdl-shadow--6dp")
    description_paragraphs = description_section.find_all("p")
    rocket_data["description"] = " ".join([para.text.strip() for para in description_paragraphs]) if description_paragraphs else None

    # Extract Mission Statistics
    stats_section = description_section.find("div", class_="mdl-grid a")
    if stats_section:
        stats = {}
        for stat in stats_section.find_all("div", class_="mdl-cell"):
            key_value = stat.text.split(":")
            if len(key_value) == 2:
                key = key_value[0].strip().replace(" ", "_").lower()
                value = key_value[1].strip()
                stats[key] = value
        rocket_data["mission_statistics"] = stats

    configurations = []
    config_heading = soup.find("h3", class_="section--center mdl-grid title", string="Configurations")
    
    if config_heading:
        for sibling in config_heading.find_all_next():
            if sibling.name == "h3" and sibling.string.strip() == "Launch Sites":
                break 

            if sibling.name == "section" and "card section--center mdl-grid mdl-grid--no-spacing mdl-shadow--6dp" in ' '.join(sibling.get("class", [])):
                config_data = {}

                # Extract Configuration Name
                config_name_tag = sibling.find("div", class_="mdl-card__title-text")
                if config_name_tag:
                    config_data["name"] = config_name_tag.text.strip()

                # Extract Image URL from the <style> section immediately preceding this section
                style_tag = sibling.find_previous("style")
                if style_tag:
                    # Match the relevant background image URL
                    match = re.search(r'\.rocket_image\.\w+\s*{\s*background:\s*url\((.*?)\)', style_tag.string)
                    if match:
                        config_data["image_url"] = match.group(1).strip('"')

                # Extract Detailed Information
                details = {}
                details_section = sibling.find("div", class_="mdl-card__supporting-text")
                
                if details_section:
                    # Initialize a variable to store the company name
                    company_name = None
                    
                    for detail in details_section.find_all("div", class_="mdl-cell"):
                        # Check if the detail contains a key-value pair (with ":")
                        if ":" in detail.text:
                            detail_key_value = detail.text.split(":")
                            if len(detail_key_value) == 2:
                                key = detail_key_value[0].strip().replace(" ", "_").lower()
                                value = detail_key_value[1].strip()
                                details[key] = value
                        else:
                            # If no ":" is found, assume it's the company name
                            company_name = detail.text.strip()
                
                    # Store the company name in the config_data
                    config_data["company_name"] = company_name
                
                # Store the details dictionary in the config_data
                config_data["details"] = details
                if config_data.get("name"):
                    configurations.append(config_data)

    # Add configurations to rocket data
    rocket_data["configurations"] = configurations

    # Scraping the launch sites
    launch_sites = []
    launch_sites_heading = soup.find("h3", class_="section--center mdl-grid title", string="Launch Sites")
    if launch_sites_heading:
        for sibling in launch_sites_heading.find_all_next():
            
            # Stop when reaching a section that is not a launch site
            if sibling.name == "h3":
                break 
            
            # Check if the sibling is a launch site section
            if sibling.name == "section" and "card section--center mdl-grid mdl-grid--no-spacing mdl-shadow--6dp" in ' '.join(sibling.get("class", [])):
                launch_site_data = sibling.find("h5", style=re.compile("margin"))
                launch_site_name = launch_site_data.text.strip() if launch_site_data else None
                
                # Append the launch site to the list only if it has a name
                if launch_site_name:
                    launch_sites.append(launch_site_name)

    # Add launch sites to rocket data
    rocket_data["launch_sites"] = launch_sites
    
    return rocket_data

# %%
# Example usage:
scrape_rocket_data("https://nextspaceflight.com/rockets/3")
# Out:
# {'rocket_name': 'Falcon 9',
#  'rocket_details_link': 'https://nextspaceflight.com/rockets/3',
#  'rocket_id': '3',
#  'description': "Falcon 9 is a partially reusable two-stage-to-orbit launch vehicle designed and manufactured by SpaceX in the United States. Both the first and second stages are powered by Merlin engines, using cryogenic liquid oxygen and rocket-grade kerosene (RP-1) as propellants. Unlike most rockets in service, which are expendable launch systems, Falcon 9 is partially reusable. The first stage is capable of re-entering the atmosphere and landing vertically after separating from the second stage. First-stage landings can occur either back at the launch site or downrange on droneships. In addition to the first stage, Falcon 9's payload fairing is also reusable. The payload fairing halves utilize a parafoil to steer themselves toward a recovery vessel.",
#  'mission_statistics': {'missions': '383',
#   'successes': '379',
#   'partial_failures': '1',
#   'failures': '3',
#   'success_streak': '28',
#   'success_rate': '99.1%'},
#  'configurations': [{'name': 'Falcon 9 Block 1 (v1.0)',
#    'image_url': 'https://storage.googleapis.com/nextspaceflight/media/rockets/Falcon_9_Block_1_rocket.webp',
#    'company_name': 'SpaceX',
#    'details': {'status': 'Retired',
#     'price': '$59.5 million',
#     'liftoff_thrust': '4,940 kN',
#     'payload_to_leo': '10,450 kg',
#     'payload_to_gto': '4,540 kg',
#     'stages': '2',
#     'strap-ons': '0',
#     'rocket_height': '54.9 m',
#     'fairing_diameter': '5.2 m',
#     'fairing_height': '13.0 m'}},
#   {'name': 'Falcon 9 Block 2 (v1.1)',
#    'image_url': 'https://storage.googleapis.com/nextspaceflight/media/rockets/Falcon_9_Block_2.webp',
#    'company_name': 'SpaceX',
#    'details': {'status': 'Retired',
#     'price': '$56.5 million',
#     'liftoff_thrust': '5,885 kN',
#     'payload_to_leo': '13,150 kg',
#     'payload_to_gto': '4,850 kg',
#     'stages': '2',
#     'strap-ons': '0',
#     'rocket_height': '68.4 m',
#     'fairing_diameter': '5.2 m',
#     'fairing_height': '13.0 m'}},
#   {'name': 'Falcon 9 Block 3 (v1.2/FT)',
#    'image_url': 'https://storage.googleapis.com/nextspaceflight/media/rockets/Falcon_9_Block_3_rocket.webp',
#    'company_name': 'SpaceX',
#    'details': {'status': 'Retired',
#     'price': '$62.0 million',
#     'liftoff_thrust': '6,804 kN',
#     'payload_to_leo': '22,800 kg',
#     'payload_to_gto': '8,300 kg',
#     'stages': '2',
#     'strap-ons': '0',
#     'rocket_height': '70.0 m',
#     'fairing_diameter': '5.2 m',
#     'fairing_height': '13.0 m'}},
#   {'name': 'Falcon 9 Block 4',
#    'image_url': 'https://storage.googleapis.com/nextspaceflight/media/rockets/Falcon_9_Block_4_rocket.webp',
#    'company_name': 'SpaceX',
#    'details': {'status': 'Retired',
#     'price': '$62.0 million',
#     'liftoff_thrust': '6,804 kN',
#     'payload_to_leo': '22,800 kg',
#     'payload_to_gto': '8,300 kg',
#     'stages': '2',
#     'strap-ons': '0',
#     'rocket_height': '70.0 m',
#     'fairing_diameter': '5.2 m',
#     'fairing_height': '13.0 m'}},
#   {'name': 'Falcon 9 Block 5',
#    'image_url': 'https://storage.googleapis.com/nextspaceflight/media/rockets/Falcon_9_Block_5.webp',
#    'company_name': 'SpaceX',
#    'details': {'status': 'Active',
#     'price': '$69.75 million',
#     'liftoff_thrust': '7,607 kN',
#     'payload_to_leo': '22,800 kg',
#     'payload_to_gto': '8,300 kg',
#     'stages': '2',
#     'strap-ons': '0',
#     'rocket_height': '70.0 m',
#     'fairing_diameter': '5.2 m',
#     'fairing_height': '13.0 m'}}],
#  'launch_sites': ['LC-39A, Kennedy Space Center, Florida, USA',
#   'SLC-40, Cape Canaveral SFS, Florida, USA',
#   'SLC-4E, Vandenberg SFB, California, USA',
#   'SLC-6, Vandenberg SFB, California, USA']}

# %%
# Function to make a request with retry mechanism and timeout
def fetch_url(url, max_retries=3, timeout=15):
    attempts = 0
    while attempts < max_retries:
        try:
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
            }
            response = requests.get(url, headers=headers, timeout=timeout)
            response.raise_for_status()  # Raise an exception for HTTP errors
            return response.text
        except requests.exceptions.RequestException as e:
            attempts += 1
            print(f"Attempt {attempts}/{max_retries} failed for {url}: {e}")
            if attempts < max_retries:
                time.sleep(2)  # Wait before retrying
            else:
                print(f"Giving up on {url} after {max_retries} attempts.")
    return None

# %%
# Function to create a list of URLs to scrape from
def create_url_array(base_url, pages):
    return [f"{base_url}?search="] + [f"{base_url}?page={i}&search=" for i in range(2, pages+1)]

# %%
# Function to collect detail page URLs
def collect_detail_urls(url_array):
    detail_urls = []
    for url in url_array:
        page_content = fetch_url(url)
        if page_content:
            soup = BeautifulSoup(page_content, 'html.parser')
            links = soup.find_all(class_='mdc-button')
            for link in links:
                if link['href'][0] == '/':
                    detail_url = f"https://nextspaceflight.com{link['href']}"
                    detail_urls.append(detail_url)
    return detail_urls

# %%
# Function to scrape data and count successes, failures, and collect failed URLs
def scrape_with_counts(detail_urls, scrape_function):
    data = []
    failed_urls = []  # List to hold failed URLs
    success_counter, fail_counter = 0, 0  # Initialize counters

    for url in detail_urls:
        try:
            result = scrape_function(url)
            if result:
                data.append(result)
                success_counter += 1
                print(f"Scraped {url} (Success Count: {success_counter})")
            else:
                failed_urls.append(url)
                fail_counter += 1
                print(f"Failed to scrape {url}. (Total Failures: {fail_counter})")
        except Exception as e:
            failed_urls.append(url)
            fail_counter += 1
            print(f"Error scraping {url}: {e} (Total Failures: {fail_counter})")

    return data, success_counter, fail_counter, failed_urls

# %%
# Configurations
rocket_config = {
    "base_url": "https://nextspaceflight.com/rockets/",
    "pages": 8,
    "output": "data_json/rockets.json"
}

# Generate URL array and collect detail URLs
url_array = create_url_array(rocket_config["base_url"], rocket_config["pages"])
detail_urls = collect_detail_urls(url_array)

# Scrape rocket data data and collect failed URLs
rocket_data, total_success, total_failures, failed_urls = scrape_with_counts(detail_urls, scrape_rocket_data)

print(f"Total Success: {total_success}, Total Failures: {total_failures}.")
print(f"Rocket scraping complete. Data saved to '{rocket_output_json_path}'.")

# Write the scraped data to a JSON file
rocket_output_json_path = rocket_config["output"]
with open(rocket_output_json_path, 'w') as json_file:
    json.dump(rocket_data, json_file, indent=4)
# Out:
# Scraped https://nextspaceflight.com/rockets/62 (Success Count: 1)
# Scraped https://nextspaceflight.com/rockets/252 (Success Count: 2)
# Scraped https://nextspaceflight.com/rockets/183 (Success Count: 3)
# Scraped https://nextspaceflight.com/rockets/58 (Success Count: 4)
# Scraped https://nextspaceflight.com/rockets/26 (Success Count: 5)
# Scraped https://nextspaceflight.com/rockets/9 (Success Count: 6)
# Scraped https://nextspaceflight.com/rockets/88 (Success Count: 7)
# Scraped https://nextspaceflight.com/rockets/89 (Success Count: 8)
# Scraped https://nextspaceflight.com/rockets/90 (Success Count: 9)
# Scraped https://nextspaceflight.com/rockets/91 (Success Count: 10)
# Scraped https://nextspaceflight.com/rockets/92 (Success Count: 11)
# Scraped https://nextspaceflight.com/rockets/33 (Success Count: 12)
# Scraped https://nextspaceflight.com/rockets/68 (Success Count: 13)
# Scraped https://nextspaceflight.com/rockets/93 (Success Count: 14)
# Scraped https://nextspaceflight.com/rockets/204 (Success Count: 15)
# Scraped https://nextspaceflight.com/rockets/205 (Success Count: 16)
# Scraped https://nextspaceflight.com/rockets/181 (Success Count: 17)
# Scraped https://nextspaceflight.com/rockets/220 (Success Count: 18)
# Scraped https://nextspaceflight.com/rockets/222 (Success Count: 19)
# Scraped https://nextspaceflight.com/rockets/229 (Success Count: 20)
# Scraped https://nextspaceflight.com/rockets/228 (Success Count: 21)
# Scraped https://nextspaceflight.com/rockets/95 (Success Count: 22)
# Scraped https://nextspaceflight.com/rockets/94 (Success Count: 23)
# Scraped https://nextspaceflight.com/rockets/232 (Success Count: 24)
# Scraped https://nextspaceflight.com/rockets/233 (Success Count: 25)
# Scraped https://nextspaceflight.com/rockets/212 (Success Count: 26)
# Scraped https://nextspaceflight.com/rockets/234 (Success Count: 27)
# Scraped https://nextspaceflight.com/rockets/235 (Success Count: 28)
# Scraped https://nextspaceflight.com/rockets/213 (Success Count: 29)
# Scraped https://nextspaceflight.com/rockets/236 (Success Count: 30)
# Scraped https://nextspaceflight.com/rockets/25 (Success Count: 31)
# Scraped https://nextspaceflight.com/rockets/64 (Success Count: 32)
# Scraped https://nextspaceflight.com/rockets/211 (Success Count: 33)
# Scraped https://nextspaceflight.com/rockets/225 (Success Count: 34)
# Scraped https://nextspaceflight.com/rockets/288 (Success Count: 35)
# Scraped https://nextspaceflight.com/rockets/184 (Success Count: 36)
# Scraped https://nextspaceflight.com/rockets/208 (Success Count: 37)
# Scraped https://nextspaceflight.com/rockets/209 (Success Count: 38)
# Scraped https://nextspaceflight.com/rockets/135 (Success Count: 39)
# Scraped https://nextspaceflight.com/rockets/215 (Success Count: 40)
# Scraped https://nextspaceflight.com/rockets/267 (Success Count: 41)
# Scraped https://nextspaceflight.com/rockets/263 (Success Count: 42)
# Scraped https://nextspaceflight.com/rockets/264 (Success Count: 43)
# Scraped https://nextspaceflight.com/rockets/202 (Success Count: 44)
# Scraped https://nextspaceflight.com/rockets/169 (Success Count: 45)
# Scraped https://nextspaceflight.com/rockets/265 (Success Count: 46)
# Scraped https://nextspaceflight.com/rockets/244 (Success Count: 47)
# Scraped https://nextspaceflight.com/rockets/245 (Success Count: 48)
# Scraped https://nextspaceflight.com/rockets/248 (Success Count: 49)
# Scraped https://nextspaceflight.com/rockets/254 (Success Count: 50)
# Scraped https://nextspaceflight.com/rockets/268 (Success Count: 51)
# Scraped https://nextspaceflight.com/rockets/269 (Success Count: 52)
# Scraped https://nextspaceflight.com/rockets/7 (Success Count: 53)
# Scraped https://nextspaceflight.com/rockets/170 (Success Count: 54)
# Scraped https://nextspaceflight.com/rockets/98 (Success Count: 55)
# Scraped https://nextspaceflight.com/rockets/97 (Success Count: 56)
# Scraped https://nextspaceflight.com/rockets/270 (Success Count: 57)
# Scraped https://nextspaceflight.com/rockets/272 (Success Count: 58)
# Scraped https://nextspaceflight.com/rockets/266 (Success Count: 59)
# Scraped https://nextspaceflight.com/rockets/271 (Success Count: 60)
# Scraped https://nextspaceflight.com/rockets/66 (Success Count: 61)
# Scraped https://nextspaceflight.com/rockets/192 (Success Count: 62)
# Scraped https://nextspaceflight.com/rockets/4 (Success Count: 63)
# Scraped https://nextspaceflight.com/rockets/59 (Success Count: 64)
# Scraped https://nextspaceflight.com/rockets/41 (Success Count: 65)
# Scraped https://nextspaceflight.com/rockets/298 (Success Count: 66)
# Scraped https://nextspaceflight.com/rockets/65 (Success Count: 67)
# Scraped https://nextspaceflight.com/rockets/171 (Success Count: 68)
# Scraped https://nextspaceflight.com/rockets/3 (Success Count: 69)
# Scraped https://nextspaceflight.com/rockets/104 (Success Count: 70)
# Scraped https://nextspaceflight.com/rockets/190 (Success Count: 71)
# Scraped https://nextspaceflight.com/rockets/294 (Success Count: 72)
# Scraped https://nextspaceflight.com/rockets/35 (Success Count: 73)
# Scraped https://nextspaceflight.com/rockets/105 (Success Count: 74)
# Scraped https://nextspaceflight.com/rockets/280 (Success Count: 75)
# Scraped https://nextspaceflight.com/rockets/101 (Success Count: 76)
# Scraped https://nextspaceflight.com/rockets/80 (Success Count: 77)
# Scraped https://nextspaceflight.com/rockets/179 (Success Count: 78)
# Scraped https://nextspaceflight.com/rockets/180 (Success Count: 79)
# Scraped https://nextspaceflight.com/rockets/81 (Success Count: 80)
# Scraped https://nextspaceflight.com/rockets/82 (Success Count: 81)
# Scraped https://nextspaceflight.com/rockets/285 (Success Count: 82)
# Scraped https://nextspaceflight.com/rockets/51 (Success Count: 83)
# Scraped https://nextspaceflight.com/rockets/150 (Success Count: 84)
# Scraped https://nextspaceflight.com/rockets/297 (Success Count: 85)
# Scraped https://nextspaceflight.com/rockets/189 (Success Count: 86)
# Scraped https://nextspaceflight.com/rockets/46 (Success Count: 87)
# Scraped https://nextspaceflight.com/rockets/281 (Success Count: 88)
# Scraped https://nextspaceflight.com/rockets/295 (Success Count: 89)
# Scraped https://nextspaceflight.com/rockets/77 (Success Count: 90)
# Scraped https://nextspaceflight.com/rockets/303 (Success Count: 91)
# Scraped https://nextspaceflight.com/rockets/38 (Success Count: 92)
# Scraped https://nextspaceflight.com/rockets/107 (Success Count: 93)
# Scraped https://nextspaceflight.com/rockets/106 (Success Count: 94)
# Scraped https://nextspaceflight.com/rockets/78 (Success Count: 95)
# Scraped https://nextspaceflight.com/rockets/45 (Success Count: 96)
# Scraped https://nextspaceflight.com/rockets/10 (Success Count: 97)
# Scraped https://nextspaceflight.com/rockets/110 (Success Count: 98)
# Scraped https://nextspaceflight.com/rockets/111 (Success Count: 99)
# Scraped https://nextspaceflight.com/rockets/112 (Success Count: 100)
# Scraped https://nextspaceflight.com/rockets/113 (Success Count: 101)
# Scraped https://nextspaceflight.com/rockets/114 (Success Count: 102)
# Scraped https://nextspaceflight.com/rockets/115 (Success Count: 103)
# Scraped https://nextspaceflight.com/rockets/119 (Success Count: 104)
# Scraped https://nextspaceflight.com/rockets/120 (Success Count: 105)
# Scraped https://nextspaceflight.com/rockets/121 (Success Count: 106)
# Scraped https://nextspaceflight.com/rockets/122 (Success Count: 107)
# Scraped https://nextspaceflight.com/rockets/123 (Success Count: 108)
# Scraped https://nextspaceflight.com/rockets/124 (Success Count: 109)
# Scraped https://nextspaceflight.com/rockets/125 (Success Count: 110)
# Scraped https://nextspaceflight.com/rockets/126 (Success Count: 111)
# Error scraping https://nextspaceflight.com/rockets/185: 'NoneType' object has no attribute 'find_all' (Total Failures: 1)
# Scraped https://nextspaceflight.com/rockets/302 (Success Count: 112)
# Scraped https://nextspaceflight.com/rockets/108 (Success Count: 113)
# Scraped https://nextspaceflight.com/rockets/301 (Success Count: 114)
# Scraped https://nextspaceflight.com/rockets/178 (Success Count: 115)
# Scraped https://nextspaceflight.com/rockets/28 (Success Count: 116)
# Scraped https://nextspaceflight.com/rockets/127 (Success Count: 117)
# Scraped https://nextspaceflight.com/rockets/128 (Success Count: 118)
# Scraped https://nextspaceflight.com/rockets/129 (Success Count: 119)
# Scraped https://nextspaceflight.com/rockets/176 (Success Count: 120)
# Scraped https://nextspaceflight.com/rockets/172 (Success Count: 121)
# Scraped https://nextspaceflight.com/rockets/197 (Success Count: 122)
# Scraped https://nextspaceflight.com/rockets/140 (Success Count: 123)
# Scraped https://nextspaceflight.com/rockets/57 (Success Count: 124)
# Scraped https://nextspaceflight.com/rockets/130 (Success Count: 125)
# Scraped https://nextspaceflight.com/rockets/131 (Success Count: 126)
# Scraped https://nextspaceflight.com/rockets/61 (Success Count: 127)
# Scraped https://nextspaceflight.com/rockets/284 (Success Count: 128)
# Scraped https://nextspaceflight.com/rockets/67 (Success Count: 129)
# Scraped https://nextspaceflight.com/rockets/99 (Success Count: 130)
# Scraped https://nextspaceflight.com/rockets/100 (Success Count: 131)
# Scraped https://nextspaceflight.com/rockets/53 (Success Count: 132)
# Scraped https://nextspaceflight.com/rockets/289 (Success Count: 133)
# Scraped https://nextspaceflight.com/rockets/63 (Success Count: 134)
# Error scraping https://nextspaceflight.com/rockets/286: 'NoneType' object has no attribute 'find_all' (Total Failures: 2)
# Scraped https://nextspaceflight.com/rockets/132 (Success Count: 135)
# Scraped https://nextspaceflight.com/rockets/193 (Success Count: 136)
# Error scraping https://nextspaceflight.com/rockets/282: 'NoneType' object has no attribute 'find_all' (Total Failures: 3)
# Scraped https://nextspaceflight.com/rockets/134 (Success Count: 137)
# Scraped https://nextspaceflight.com/rockets/133 (Success Count: 138)
# Scraped https://nextspaceflight.com/rockets/40 (Success Count: 139)
# Scraped https://nextspaceflight.com/rockets/34 (Success Count: 140)
# Scraped https://nextspaceflight.com/rockets/296 (Success Count: 141)
# Scraped https://nextspaceflight.com/rockets/231 (Success Count: 142)
# Scraped https://nextspaceflight.com/rockets/83 (Success Count: 143)
# Scraped https://nextspaceflight.com/rockets/151 (Success Count: 144)
# Scraped https://nextspaceflight.com/rockets/258 (Success Count: 145)
# Scraped https://nextspaceflight.com/rockets/223 (Success Count: 146)
# Scraped https://nextspaceflight.com/rockets/283 (Success Count: 147)
# Scraped https://nextspaceflight.com/rockets/37 (Success Count: 148)
# Scraped https://nextspaceflight.com/rockets/259 (Success Count: 149)
# Scraped https://nextspaceflight.com/rockets/60 (Success Count: 150)
# Scraped https://nextspaceflight.com/rockets/29 (Success Count: 151)
# Scraped https://nextspaceflight.com/rockets/152 (Success Count: 152)
# Scraped https://nextspaceflight.com/rockets/153 (Success Count: 153)
# Scraped https://nextspaceflight.com/rockets/230 (Success Count: 154)
# Scraped https://nextspaceflight.com/rockets/75 (Success Count: 155)
# Scraped https://nextspaceflight.com/rockets/72 (Success Count: 156)
# Scraped https://nextspaceflight.com/rockets/48 (Success Count: 157)
# Scraped https://nextspaceflight.com/rockets/299 (Success Count: 158)
# Error scraping https://nextspaceflight.com/rockets/300: 'NoneType' object has no attribute 'find_all' (Total Failures: 4)
# Scraped https://nextspaceflight.com/rockets/5 (Success Count: 159)
# Scraped https://nextspaceflight.com/rockets/32 (Success Count: 160)
# Scraped https://nextspaceflight.com/rockets/173 (Success Count: 161)
# Scraped https://nextspaceflight.com/rockets/292 (Success Count: 162)
# Scraped https://nextspaceflight.com/rockets/194 (Success Count: 163)
# Scraped https://nextspaceflight.com/rockets/141 (Success Count: 164)
# Scraped https://nextspaceflight.com/rockets/142 (Success Count: 165)
# Scraped https://nextspaceflight.com/rockets/143 (Success Count: 166)
# Scraped https://nextspaceflight.com/rockets/216 (Success Count: 167)
# Scraped https://nextspaceflight.com/rockets/144 (Success Count: 168)
# Scraped https://nextspaceflight.com/rockets/195 (Success Count: 169)
# Scraped https://nextspaceflight.com/rockets/196 (Success Count: 170)
# Scraped https://nextspaceflight.com/rockets/145 (Success Count: 171)
# Scraped https://nextspaceflight.com/rockets/36 (Success Count: 172)
# Scraped https://nextspaceflight.com/rockets/257 (Success Count: 173)
# Scraped https://nextspaceflight.com/rockets/146 (Success Count: 174)
# Scraped https://nextspaceflight.com/rockets/147 (Success Count: 175)
# Scraped https://nextspaceflight.com/rockets/79 (Success Count: 176)
# Scraped https://nextspaceflight.com/rockets/47 (Success Count: 177)
# Scraped https://nextspaceflight.com/rockets/174 (Success Count: 178)
# Scraped https://nextspaceflight.com/rockets/156 (Success Count: 179)
# Scraped https://nextspaceflight.com/rockets/167 (Success Count: 180)
# Scraped https://nextspaceflight.com/rockets/206 (Success Count: 181)
# Scraped https://nextspaceflight.com/rockets/74 (Success Count: 182)
# Scraped https://nextspaceflight.com/rockets/86 (Success Count: 183)
# Scraped https://nextspaceflight.com/rockets/276 (Success Count: 184)
# Scraped https://nextspaceflight.com/rockets/102 (Success Count: 185)
# Scraped https://nextspaceflight.com/rockets/242 (Success Count: 186)
# Scraped https://nextspaceflight.com/rockets/241 (Success Count: 187)
# Scraped https://nextspaceflight.com/rockets/262 (Success Count: 188)
# Scraped https://nextspaceflight.com/rockets/243 (Success Count: 189)
# Scraped https://nextspaceflight.com/rockets/287 (Success Count: 190)
# Scraped https://nextspaceflight.com/rockets/291 (Success Count: 191)
# Scraped https://nextspaceflight.com/rockets/55 (Success Count: 192)
# Scraped https://nextspaceflight.com/rockets/260 (Success Count: 193)
# Scraped https://nextspaceflight.com/rockets/261 (Success Count: 194)
# Scraped https://nextspaceflight.com/rockets/138 (Success Count: 195)
# Scraped https://nextspaceflight.com/rockets/207 (Success Count: 196)
# Scraped https://nextspaceflight.com/rockets/139 (Success Count: 197)
# Scraped https://nextspaceflight.com/rockets/157 (Success Count: 198)
# Scraped https://nextspaceflight.com/rockets/158 (Success Count: 199)
# Scraped https://nextspaceflight.com/rockets/52 (Success Count: 200)
# Scraped https://nextspaceflight.com/rockets/31 (Success Count: 201)
# Scraped https://nextspaceflight.com/rockets/76 (Success Count: 202)
# Scraped https://nextspaceflight.com/rockets/137 (Success Count: 203)
# Scraped https://nextspaceflight.com/rockets/177 (Success Count: 204)
# Scraped https://nextspaceflight.com/rockets/148 (Success Count: 205)
# Scraped https://nextspaceflight.com/rockets/149 (Success Count: 206)
# Scraped https://nextspaceflight.com/rockets/70 (Success Count: 207)
# Scraped https://nextspaceflight.com/rockets/50 (Success Count: 208)
# Error scraping https://nextspaceflight.com/rockets/227: 'NoneType' object has no attribute 'find_all' (Total Failures: 5)
# Scraped https://nextspaceflight.com/rockets/49 (Success Count: 209)
# Scraped https://nextspaceflight.com/rockets/191 (Success Count: 210)
# Scraped https://nextspaceflight.com/rockets/293 (Success Count: 211)
# Scraped https://nextspaceflight.com/rockets/251 (Success Count: 212)
# Total Success: 212, Total Failures: 5.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 16
#      13 rocket_data, total_success, total_failures, failed_urls = scrape_with_counts(detail_urls, scrape_rocket_data)
#      15 print(f"Total Success: {total_success}, Total Failures: {total_failures}.")
# ---> 16 print(f"Rocket scraping complete. Data saved to '{rocket_output_json_path}'.")
#      18 # Write the scraped data to a JSON file
#      19 rocket_output_json_path = rocket_config["output"]
#
# NameError: name 'rocket_output_json_path' is not defined

# %%
# Write the scraped data to a JSON file
rocket_output_json_path = rocket_config["output"]
with open(rocket_output_json_path, 'w') as json_file:
    json.dump(rocket_data, json_file, indent=4)

# %%
# Load the JSON data from the file
with open('data_json/rockets.json', 'r') as json_file:
    rockets_data = json.load(json_file)

# Initialize a list to hold the flattened records
flattened_records = []

# Define the keys you want to extract from the rocket-level data
rocket_keys = [
    'rocket_name', 
    'rocket_details_link', 
    'rocket_id', 
    'description', 
    'launch_sites'
]

# Iterate over each rocket in the JSON data
for rocket in rockets_data:
    # Create a base record for each rocket
    base_record = {key: rocket.get(key) for key in rocket_keys}
    
    # Add mission statistics to the base record
    mission_stats = rocket.get('mission_statistics', {})
    for key, value in mission_stats.items():
        base_record[f'mission_statistics_{key}'] = value

    # Iterate through configurations
    for config in rocket.get('configurations', []):
        # Create a new record for each configuration
        record = base_record.copy()
        
        # Add configuration-specific details
        record['configuration_name'] = config.get('name')
        record['configuration_image_url'] = config.get('image_url')
        record['configuration_company_name'] = config.get('company_name')
        
        # Add details from the configuration
        details = config.get('details', {})
        for detail_key, detail_value in details.items():
            record[f'configuration_detail_{detail_key}'] = detail_value

        # Append the new record to the list
        flattened_records.append(record)

# Create a DataFrame from the flattened records
df = pd.DataFrame(flattened_records)

# Convert launch_sites list to a string (optional)
df['launch_sites'] = df['launch_sites'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# Display the DataFrame
print(df[2:4].head())
# Out:
#   rocket_name                      rocket_details_link rocket_id  \
# 2    Angara 1  https://nextspaceflight.com/rockets/183       183
# 3    Angara 1  https://nextspaceflight.com/rockets/183       183
#
#                                          description  \
# 2  The Angara 1 variants use a single Universal R...
# 3  The Angara 1 variants use a single Universal R...
#
#                                         launch_sites  \
# 2  Site 1A, Vostochny Cosmodrome, Russia, Site 35...
# 3  Site 1A, Vostochny Cosmodrome, Russia, Site 35...
#
#   mission_statistics_missions mission_statistics_successes  \
# 2                           4                            4
# 3                           4                            4
#
#   mission_statistics_partial_failures mission_statistics_failures  \
# 2                                   0                           0
# 3                                   0                           0
#
#   mission_statistics_success_streak  ... configuration_detail_status  \
# 2                                 4  ...                      Active
# 3                                 4  ...                     Retired
#
#   configuration_detail_price configuration_detail_liftoff_thrust  \
# 2                        NaN                            1,922 kN
# 3                        NaN                            1,922 kN
#
#   configuration_detail_payload_to_leo configuration_detail_stages  \
# 2                            3,800 kg                           2
# 3                                 NaN                           2
#
#   configuration_detail_strap-ons configuration_detail_rocket_height  \
# 2                              0                             42.7 m
# 3                              0                             42.7 m
#
#   configuration_detail_fairing_diameter configuration_detail_fairing_height  \
# 2                                 3.0 m                               2.9 m
# 3                                 3.0 m                               2.9 m
#
#   configuration_detail_payload_to_gto
# 2                                0 kg
# 3                                0 kg
#
# [2 rows x 24 columns]

# %%
df.shape
# Out:
# (491, 24)

# %%
df.dtypes
# Out:
# rocket_name                              object
# rocket_details_link                      object
# rocket_id                                object
# description                              object
# launch_sites                             object
# mission_statistics_missions              object
# mission_statistics_successes             object
# mission_statistics_partial_failures      object
# mission_statistics_failures              object
# mission_statistics_success_streak        object
# mission_statistics_success_rate          object
# configuration_name                       object
# configuration_image_url                  object
# configuration_company_name               object
# configuration_detail_status              object
# configuration_detail_price               object
# configuration_detail_liftoff_thrust      object
# configuration_detail_payload_to_leo      object
# configuration_detail_stages              object
# configuration_detail_strap-ons           object
# configuration_detail_rocket_height       object
# configuration_detail_fairing_diameter    object
# configuration_detail_fairing_height      object
# configuration_detail_payload_to_gto      object
# dtype: object
